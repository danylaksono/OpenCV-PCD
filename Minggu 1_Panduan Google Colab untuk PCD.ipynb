# %% [markdown]
# #**Panduan Google Colab untuk Pengolahan Citra Digital**

# %% [markdown]
# ## **Pendahuluan**
#
#
# **OpenCV** [(opencv.org)](opencv.org) merupakan sebuah framework yang banyak digunakan untuk keperluan pemrosesan image dan video. OpenCV bersifat gratis dan tersedia untuk berbagai bahasa pemrograman, seperti C++, Python, Java dan
# lain-lain pada platform Windows, Linux, iOS, Android dan seterusnya. OpenCV dapat digunakan untuk melakukan berbagai operasi terhadap citra dan video dengan berbagai algoritma terbaru serta banyak digunakan pada berbagai sistem pengolahan citra yang populer.
#
# **Python** [(python.org)](python.org) merupakan salah satu bahasa pemrograman yang paling banyak digunakan di dunia. Python merupakan bahasa yang dikembangkan untuk keperluan umum dan dilengkapi dengan berbagai package atau library yang mendukung banyak fungsi yang spesifik, seperti *numpy* (pengolahan matriks seperti Matlab), *scipy* (pengolahan data statistik), *bokeh* (visualisasi dan data analitik), *flask* (framework untuk web berbasis Python), dan lain sebagainya. OpenCV sendiri merupakan salah satu *library* yang juga dibuat dalam bahasa Python sehingga memudahkan penggunaannya untuk keperluan pemrosesan citra dalam lingkungan Python. Saat ini terdapat dua versi besar Python yang beredar, yaitu versi 2.x dan versi 3.x.
#
# **Google Colaboratory**  [(https://colab.research.google.com/](https://colab.research.google.com/) merupakan perangkat komputasi awan (*cloud computing*) yang dibuat oleh Google dengan tujuan untuk memudahkan kegiatan pembelajaran dan pengolahan data dengan mudah menggunakan antarmuka berbasis Jupyter Notebook atau iPython *(interactive Python)*. Google Colab menyediakan sebuah platform komputasi gratis berupa komputer virtual untuk setiap penggunanya yang dilengkapi dengan kemampuan pengolahan data yang memadai. Dengan memanfaatkan Google Colab, pengguna tidak perlu melakukan instalasi atau pengaturan yang rumit untuk keperluan pengolahan data dengan menggunakan Python.
#
# Google Colab dilengkapi dengan beberapa modul Python bawaan, seperti **numpy** dan **OpenCV** sehingga pengguna dapat memanfaatkan platform ini untuk melakukan pengolahan citra sederhana. Pada bagian ini akan dijelaskan dasar penggunaan Google Colab untuk melakukan pengolahan citra digital menggunakan Python.

# %% [markdown]
# ## *Menggunakan Google Colab*

# %% [markdown]
# ### Memanggil Notebook Google Colab
# Google Colab dapat diakses secara gratis oleh semua pengguna yang memiliki akun Google. Setiap Google Colab terdiri atas dokumen yang disebut dengan **notebook**, yang sebenarnya merupakan sebuah dokumen Interactive Python Notebook (ipynb). Oleh Google Colab, notebook tersebut dapat dijalankan layaknya sebuah dokumen yang dipanggil menggunakan interpreter bahasa Python.
#
# Untuk memanggil Google Colab, dapat dilakukan dengan cara membuka Google Drive pada folder tertentu, kemudian klik kanan pada folder tersebut, dan pilih **New > Google Colaboratory**. Selanjutnya, Google Colab siap untuk digunakan.
#
# ![alt text](https://drive.google.com/uc?id=19cY2TqAo7WOP3MGwsfZnfDrjHteU7BWa)
#
# Apabila pilihan Google Colaboratory tidak dijumpai, maka terlebih dahulu lakukan instalasi melalui **Connect more Apps**.
#
# Selanjutnya, Google akan membuat sebuah file dengan ekstensi ipynb pada folder tersebut. File ini adalah sebuah Notebook iPython yang dapat digunakan untuk menjalankan perintah-perintah dalam bahasa Python.

# %% [markdown]
# ### Memanggil file yang tersimpan pada GDrive di Google Colab
#
# Untuk memanggil file di Google Drive pada GColab, terlebih dahulu harus dilakukan 'Mounting' untuk menghubungkan antara Google Drive dan Google Colab. Hal ini dapat dilakukan menggunakan menu **Mount Drive** pada bagian kanan Notebook.
#
# ![Mount Drive](https://drive.google.com/uc?id=1GhA4RtduZsKZ3BV0SoaSDiT0rQBbJlpV)
#
# Untuk latihan, terlebih dahulu unduh, kemudian unggah file berikut pada Google Drive di folder yang sama dengan file ipynb yang sudah dibuat sebelumnya:
#
# [unduh file.txt](https://drive.google.com/uc?id=1oP0r1NQK7gLLMpiw_30EqeytpLeWtAd2)
#
# Selanjutnya, gunakan opsi Copy Path pada Google Colab untuk mendapatkan path atau tempat penyimpanan file.txt di Google Drive:
#
# ![Copy Path](https://drive.google.com/uc?id=1RvneSXJQ285PUphG8QA6c1GJQDBbmetH)
#
# Gunakan path yang sudah tercopy pada baris kode berikut ini:

# %%
with open('/content/drive/My Drive/Akademik Geodesi/Geodesi/Pengolahan Citra Digital/file.txt') as f:
    for line in f:
        print(line.strip())
# Out:
# ini adalah isi dari file.txt
# isinya hanya dua baris

# %% [markdown]
# Selain itu, perintah **wget** juga dapat digunakan untuk memanggil file dari sumber luar. Jalankan cell berikut sebagai contoh

# %%
# perintah wget dapat digunakan untuk mengunduh file dari sumber lain 
# dan menyimpan pada Google Drive yang sudah terkoneksi
# !wget https://drive.google.com/uc?id=1oP0r1NQK7gLLMpiw_30EqeytpLeWtAd2 -O file2.txt

# ls atau list digunakan untuk menampilkan isi dari folder pada OS berbasis Unix
# !ls
# Out:
# --2020-02-11 23:37:13--  https://drive.google.com/uc?id=1oP0r1NQK7gLLMpiw_30EqeytpLeWtAd2
# Resolving drive.google.com (drive.google.com)... 74.125.204.100, 74.125.204.102, 74.125.204.101, ...
# Connecting to drive.google.com (drive.google.com)|74.125.204.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-00-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/49vut5hp9i0qapn4dlmhrk12b2akr8a3/1581463800000/10973890960709691040/*/1oP0r1NQK7gLLMpiw_30EqeytpLeWtAd2 [following]
# ...
# --2020-02-11 23:37:13--  https://doc-00-7c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/49vut5hp9i0qapn4dlmhrk12b2akr8a3/1581463800000/10973890960709691040/*/1oP0r1NQK7gLLMpiw_30EqeytpLeWtAd2
# Resolving doc-00-7c-docs.googleusercontent.com (doc-00-7c-docs.googleusercontent.com)... 64.233.188.132, 2404:6800:4008:c06::84
# ...

# %% [markdown]
# ## *Menggunakan Python pada Google Colab*
#
# Python adalah bahasa pemrograman [paling populer](https://pypl.github.io/PYPL.html) saat ini. Kepopuleran Python diantaranya disebabkan oleh dukungan yang luas untuk berbagai keperluan analisis data, termasuk big data, machine learning dan deep learning. Disamping itu, Python merupakan bahasa pemrograman yang paling mudah dipelajari. *Nggak percaya?*
#
# >![parseltongue](https://drive.google.com/uc?id=1nHt4AsDRfXCVKtmyTAFGBt_fhqUwJf4y)
#
#
# Google Colab, seperti yang telah disebutkan di atas, merupakan salah satu antarmuka untuk pemrograman bahasa Python. Notebook yang dibuat dengan Google Colab dapat disimpan dan dibagikan sehingga memudahkan siapapun untuk berbagi-pakai kode Ptyhon di dalamnya. Sebuah dokumen Google Colab merupakan file dengan ekstensi *.ipynb, yang terdiri dari baris-baris perintah dalam bahasa Python.
#
# Tiap dokumen ipynb pada Google Colab terdiri dari beberapa **cell**, dimana masing-masing cell tersebut dapat berisi beberapa baris teks (dalam format markdown) atau beberapa baris kode dalam bahasa Python (default menggunakan Python versi 3). untuk itu, baris kode seperti berikut dapat dibuat pada sebuah cell di Google Colab:
#
# ```
# print("hello world")
# ```
#
# selanjutnya, tekan **Shift+Enter** untuk menjalankan cell tersebut. Hasilnya akan ditampilkan di bagian bawah dari tiap cell.
# Sebagai contoh, apabila cell di bawah ini dijalankan, maka hasilnya berupa beberapa baris keluaran dari perintah *'print'* akan dicetak pada bagian bawah cell

# %% [markdown]
# ### Baris perintah Python sederhana
#
# Jalankan cell di bawah ini dan lakukan modifikasi untuk melihat bagaimana Python digunakan pada Google Colab

# %%
# ini adalah komentar pada baris python
# mencetak ke layar menggunakan perintah 'print'
print("hello world!")

# mendefinisikan variabel
x = 5
y = 6

# operasi artimatika sederhana
hasil = x*y+2*x-2*y

# mencetak hasil ke keluaran
print('hasil dari operasi adalah', hasil)

# variabel juga dapat didefinisikan sekaligus, dipisahkan oleh tanda koma
var1, var2 = 23.5, "ini adalah isi var2"

print("isi var1: ", var1, "\nisi var2: ", var2)
# Out:
# hello world!
# hasil dari operasi adalah 28
# isi var1:  23.5
# isi var2:  ini adalah isi var2

# %% [markdown]
# ### Tipe Data
# Pada Python, tipe data tidak perlu didefinisikan secara explisit. Python akan mengenali secara otomatis tipe data tiap kali sebuah variabel didefinisikan. Apabila operasi aritmatika dilakukan pada dua variabel dengan tipe data yang tidak sesuai, Python akan memunculkan error. Cell-cell berikut menunjukkan beberapa jenis pendefinisian tipe data pada Python

# %%
# Tipe data pada Python didefinisikan pada saat variabel dibuat

x = 5               # int
y = 6.5             # float
z = "bahasa ular"   # str

hasil = x + y       # penjumlahan antara int dan float
print(hasil)        # mencetak hasil
print(type(hasil))  # mencetak tipe data hasil
# Out:
# 11.5
# <class 'float'>

# %%
# cell berikut hanya akan bisa dijalankan 
# apabila cell di atas sudah dijalankan sebelumnya

hasil = x + z     # akan muncul error akibat penjumlahan tipe data yang tidak sesuai
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-f2439f19de68> in <module>()
#       1
# ----> 2 hasil = x + z     # akan muncul error akibat penjumlahan
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Beberapa tipe data lain pada Python

# tipe data boolean
trueOrFalse = True
print(trueOrFalse)

# tipe data array/list
ar = [[blue]], [green], [red]]    
print(ar[1])    # array pada Python dimulai dari urutan nol (0)

# tipe data dictionary
dic = {'nama buah': 'durian',
       'nama ilmiah': 'Durio Zibethinus',
       'asal': 'Malaysia',
       'persebaran': 'Asia Tenggara'
       }
print(dic['nama buah'])
# Out:
# True
# rambutan
# durian

# %% [markdown]
# ### Pernyataan Kondisi (*Conditional Statement*) dan Iterasi (*Iteration Statement*)
# Pernyataan kondisi dapat dibuat pada Python menggunakan baris perintah seperti berikut:
#
# ```
# if 5 > 2:
#   print("lima lebih dari dua lho")
# ```
#
# Satu hal penting yang perlu diperhatikan pada saat membuat penyataan kondisi adalah **indentasi**, yaitu seberapa banyak spasi yang dibuat pada suatu blok kode pernyataan kondisi maupun iterasi (seperti for). Contoh Cell-cell berikut menunjukkan kode untuk pernyataan kondisi maupun iterasi:

# %%
# pernyataan kondisional
if 5 > 2:
  print("lima lebih dari dua lho")

# operand (operasi pengujian) untuk persamaan menggunakan dua tanda sama dengan ('==')
x = 4
y = (8-x)
if x == y:
  print("x dan y sama")
else:
  print("x dan y beda")

# contoh iterasi. cell di atas (no. 9) harus dijalankan terlebih dahulu 
# agar variabel 'ar' didefinisikan
for isi in ar:
  print(isi)
# Out:
# lima lebih dari dua lho
# x dan y sama
# pepaya
# jeruk
# jambu
# rambutan
# duren
# duku

# %% [markdown]
# ### Fungsi (*Function*)
#
# Fungsi pada Python digunakan antara lain untuk menyederhanakan struktur kode pada Python, sekaligus memungkinkan fungsi untuk dapat dipanggil beberapa kali tanpa harus menuliskan kode yang sama berulang-ulang.

# %%
# mendefinisikan fungsi menggunakan 'def'
def ini_fungsi(siapaNamanya):
  print(siapaNamanya + " belajar Bahasa Ular")


# memanggil fungsi
ini_fungsi('Harry Potter')

# memanggil kembali fungsi dengan nilai parameter berbeda
ini_fungsi('Voldemort')

# lagi
ini_fungsi('Semua orang')
# Out:
# Harry Potter belajar Bahasa Ular
# Voldemort belajar Bahasa Ular
# Semua orang belajar Bahasa Ular

# %% [markdown]
# ## Memanggil Modul Python
#
# Python merupakan bahasa yang sangat kaya. Terdapat ratusan bahkan ribuan *module* yang sudah dibuat oleh berbagai komunitas Python untuk memudahkan fungsi-fungsi tertentu. Berikut adalah sedikit contoh dari beberapa Modul Python:
#
# * [PyTide](https://github.com/sam-cox/pytides/wiki/How-to-make-your-own-Tide-Table-using-Python-and-Pytides), untuk analisis pasut harmonik
# *   [Laika](https://github.com/commaai/laika), untuk pengolahan data GNSS
# *   [Python Photogrammetry Toolbox](https://github.com/steve-vincent/photogrammetry)
# * [SPy](http://www.spectralpython.net/), untuk pengolahan citra Hyperspectral
#
# Sebuah modul Python dapat berisi ratusan fungsi berbeda. Sebagai contoh, modul **'Datetime'** berisi fungsi untuk menampilkan tanggal, yaitu fungsi *date()*. Demikian juga, terdapat fungsi untuk menampilkan seluruh waktu saat ini sampai ke satuan detik, yaitu *now()*. Keseluruhan modul dapat dipanggil menggunakan perintah:
#
#  ``` import <module>```
#
# atau dapat juga dipanggil hanya fungsi tertentu pada satu modul menggunakan perintah:
#
# ```from <module> import <fungsi>```
#
# Pada praktikum Pengolahan Citra Digital ini akan digunakan beberapa modul Python untuk keperluan pengolahan citra, salah satunya bernama [OpenCV](opencv.org) yang memiliki fungsi untuk mengolah citra digital dengan fungsi Computer Vision. OpenCV dapat dipanggil pada Google Colab menggunakan perintah:
#
# ```
# import cv2
# ```
#
# berikut adalah contoh pemanggilan modul Python

# %%
# memanggil modul 'datetime' untuk menampilkan waktu
# fungsi datetime dinamakan sebagai 'dt' untuk menyingkat pemanggilan
import datetime as dt

# memanggil fungsi datetime.now pada modul datetime
x = dt.datetime.now()
print(x)


# memanggil hanya fungsi tertentu pada satu modul
from datetime import date

hariIni = date.today()

print("Hari ini tanggal: ", hariIni)
# Out:
# 2021-02-09 02:38:02.859629
# Hari ini tanggal:  2021-02-09

# %% [markdown]
# ### Menggunakan Numpy
#
# Numpy ([numpy.org](numpy.org)) merupakan modul Python yang berfungsi untuk menangani operasi Matriks. Numpy dapat digunakan untuk berbagai operasi terkait matriks, dan dapat disebut sebagai 'Matlabnya Python' karena kelengkapan fungsi yang disediakan.
#
# Dalam pengolahan citra digital, sebuah gambar atau foto dapat dianggap sebagai sebuah matriks. oleh karenanya, Numpy dapat membantu beberapa fungsi yang digunakan pada saat pengolahan citra.

# %%
# memanggil modul numpy

import numpy as np
a  = np.array([1,2,3])

# mencetak dimensi dan tipe data matriks a
print(a.shape)
print(a.dtype)
# Out:
# (3,)
# int64

# %% [markdown]
# Pada contoh di bawah ini, kita juga akan menggunakan modul **Matplotlib**. [Matplotlib](https://matplotlib.org/) merupakan modul Python yang digunakan untuk keperluan mencetak keluaran pada layar: grafik, plot, gambar, dan lain sebagainya. Kita dapat mengkombinasikan Numpy dan Matplotlib untuk mencetak berbagai grafik yang berguna untuk keperluan tertentu, misalnya menampilkan suatu histogram.
#
# <img src="https://miro.medium.com/max/2032/1*EsqDYFK-IzGEAm4FyZP0wQ.jpeg" alt="Drawing" style="width: 20px;"/>
#
# Contoh di bawah ini menunjukkan bagaimana Matplotlib digunakan untuk menampilkan sebuah histogram distribusi normal dari serangkaian angka acak yang dibuat menggunakan Numpy

# %%
# memanggil numpy dan matplotlib
import numpy
import matplotlib.pyplot as plt


# membuat distribusi normal dengan mean=5, stdev=1 dan jumlah data 100.000 
x = numpy.random.normal(5.0, 1.0, 100000)

# plotting dengan matplotlib
plt.hist(x, 100)
plt.show()

# %% [markdown]
# ### Membaca Citra Satelit dengan Modul Rasterio
#
# Terdapat banyak modul Python yang dapat digunakan untuk analisis Citra. OpenCV telah disebutkan sebelumnya di atas. Matplotlib sendiri memiliki submodul `matplotlib.image` yang dapat digunakan untuk menampilkan data raster. Scikit, paket modul yang terkenal digunakan untuk keperluan Machine Learning, memiliki modul yang disebut dengan nama `scikit-image`. Dengan banyaknya modul Python yang sangat kaya pada berbagai bidang ini yang memungkinkan Python digunakan sebagai bahasa *General Purpose Language*.
#
# Untuk keperluan pengolahan data citra pada bidang geospasial, modul-modul di atas dapat digunakan dengan baik. Terdapat juga modul yang memiliki fungsi-fungsi khusus untuk keperluan analisis dan visualisasi data raster seperti citra satelit atau foto udara. [GDAL](https://pypi.org/project/pygdal/) dan [Rasterio](https://rasterio.readthedocs.io/) adalah dua contoh modul semacam ini.

# %%
# Melakukan instalasi Rasterio
# !pip install rasterio

# %% [markdown]
# Pada contoh di atas, **Rasterio** perlu diinstall terlebih dulu, karena bukan merupakan modul yang telah tersedia pada Google Colab (berbeda dengan Numpy dan Matplotlib yang dapat langsung digunakan tanpa instalasi).
#
# PIP sendiri merupakan perintah interpreter Python yang digunakan untuk melakukan instalasi modul-modul Python. Dengan Pip, kita dapat melakukan instalasi beragam modul Python pada mesin kita untuk digunakan sebagai library. Inilah keuntungan dari penggunaan pemrograman modular: kita tinggal menggunakan modul yang sudah dibuat oleh orang lain tanpa perlu membuat ulang dari nol. Beragam modul Python yang dapat diinstall menggunakan Pip dapat dilihat pada [http://pypi.org/](http://pypi.org/).

# %% [markdown]
# Pada contoh di bawah, Rasterio dan Matplotlib digunakan untuk menampilkan plotting dari data foto udara yang tersimpan pada Cloud dalam format COG *(Cloud Optimized GeoTIFF)*. Format ini akan menjadi bahan pembahasan khusus di pertemuan lain pada mata kuliah ini

# %%
# Memanggil modul rasterio yang sudah terinstall
# Dari Matplotlib, cukup ambil modul `pyplot`, yang digunakan untuk memperbesar 
# hasil plotting dari Rasterio
import rasterio
from matplotlib import pyplot as plt

# Format COG (Cloud Optimised Geotiff), dipanggil dari OpenAerialMap
alamat_citra = 'http://oin-hotosm.s3.amazonaws.com/59fc6c5431eff4000c380554/0/a435847f-29bf-49e5-af8b-e3cfba4d4ea3.tif'
citra = rasterio.open(alamat_citra)

# perbesar ukuran hasil plotting 
plt.rcParams["figure.figsize"] = (15,15)

# Panggil submodul show pada rasterio, kemudian gunakan untuk menampilkan citra
# untuk menampilkan koordinat, gunakan parameter "transform" pada modul tersebut
from rasterio.plot import show
show(citra.read(), transform=citra.transform)

# %% [markdown]
# ## **Kesimpulan**
# Praktikum pengolahan citra digital ini dilakukan menggunakan Google Colab. Google Colab merupakan perangkat Notebook Python yang disediakan oleh Google dengan dukungan CPU dan GPU yang sangat *powerful* sehingga dapat digunakan untuk pemrosesan citra atau big data dalam jumlah sangat besar, tanpa perlu menggunakan kemampuan komputasi pada komputer masing-masing. Google Colab yang menggunakan bahasa pengantar Python dan R dapat digunakan untuk mengolah berbagai macam data, termasuk data raster berupa citra satelit.
#
#
# > *Apa Selanjutnya?*
#
# > Pertemuan selanjutnya di praktikum mata kuliah Pengolahan Citra Digital ini akan membahas mengenai bagaimana citra disusun sebagai sebuah matriks pada komputer, serta bagaimana berinteraksi dengan data citra tersebut. Untuk itu, akan digunakan OpenCV sebagai perangkat pengolahan citra level rendah untuk keperluan Computer Vision. Selanjutnya, Rasterio akan diberikan untuk menjelaskan mengenai penggunaan modul ini dalam pengolahan data-data citra satelit.

# %% [markdown]
# ## **Latihan**
#
# Untuk latihan minggu ini, kerjakan tugas dengan ketentuan:
#
# Buat sebuah file Google Colab Notebook pada Google Drive masing-masing. file inilah yang nanti akan dikumpulkan pada link yang akan diberikan pada saat kuliah. Sebagai catatan, link pada dibuat dengan menggunakan tombol share pada pojok kanan atas.
#
# Isi file Notebook tersebut adalah sebagai berikut:
#
# 1. Nama dan NIM Lengkap
#
# 2. Buat sebuah file TXT berisi baris angka dari 1-10, kemudian panggil dalam Google Colab menggunakan Python seperti contoh di atas. Jika baris tersebut berisi angka ganjil, tampilkan perkalian angka tersebut dengan dua. Jika Genap, tampilkan apa adanya
#
# > *Contoh masukan (file 'input.txt'):*
# > ```
# > 1
# > 2
# > 3
# > dst
# >10
# > ```
# > *Contoh Keluaran:*
# > ```
# > 2
# > 2
# > 6
# > dst
# > 10
# > ```
#
#
# 3. Panggil sebuah gambar (bebas, bisa berupa gambar dari internet, kemudian tampilkan dengan menggunakan Matplotlib atau Rasterio
