# %% [markdown]
# # **Operasi Image Filtering dan Thresholding**
#
# ## Konsep Filtering
#
# Filtering

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow


#bgr
img = cv2.imread('cat.jpg')

#rgb
cat = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

cv2_imshow(img)

kernel1 = np.ones((5,5),np.float32)/25
print(kernel1)


kernel = np.matrix([
          [0, 1, 0],
          [0, 1, 0],
          [0, 1, 0]         
          ])
print(kernel)



kucing_filter = cv2.filter2D(img,-1,kernel1)

cv2_imshow(kucing_filter)
# Out:
# <PIL.Image.Image image mode=RGB size=424x362 at 0x7FDEF122F5F8>
# [[0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]]
# [[0 1 0]
#  [0 1 0]
#  [0 1 0]]
# <PIL.Image.Image image mode=RGB size=424x362 at 0x7FDEF09AC390>

# %%
plt.subplot(121),plt.imshow(cat),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(kucing_filter),
plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
#highpass filter

import cv2
import numpy as np
from matplotlib import pyplot as plt


# memanggil citra sebagai grayscale (argument 0)
img = cv2.imread('sudoku.jpg',0)

# menerapkan algoritma high-pass filtering
laplacian = cv2.Laplacian(img,cv2.CV_64F)

sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

# perbesar ukuran hasil plotting 
plt.rcParams["figure.figsize"] = (20,20)


# menampilkan hasil filter
plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import ee
